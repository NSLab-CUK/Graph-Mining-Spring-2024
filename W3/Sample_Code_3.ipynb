# %% [markdown]
# # Neo4j Example Scriptse.
# ### Note: you should install Neo4j database in your computer and run these scripts in its UI application.

# %% [markdown]
# ## Add entities into graph database.

# %%
CREATE(:Book{name:'Graph Databases',published_date:'Nov 16, 2015'})
CREATE(:Person{name:'John',born:'Mar 8, 1998',linkedin:'@john'})
CREATE(:Person{name:'Sally',born:'Oct 16, 1997',linkedin:'@sali'})

# %% [markdown]
# ## Add relationship

# %%
MATCH (a:Person), (b:Person) WHERE (a.name = 'John' AND b.name = 'Sally') CREATE (a)-[r1:IS_FRIENDS_WITH]->(b);
MATCH (a:Person), (b:Book) WHERE (a.name = 'John' OR a.name = 'Sally') AND b.name = 'Graph Databases' CREATE (a)-[r2:HAS_READ]->(b);

# %% [markdown]
# ## Delete relationships

# %%
MATCH (n:Person {name: 'John'})-[r:HAS_READ]->()
DELETE r

# %% [markdown]
# ## Delete node
# You should remove all the relationship connected to these nodes before removing them

# %%
MATCH (n:Person {name: 'John'})-[r:HAS_READ]->() 
DELETE r

# %%
MATCH (n:Person {name: 'John'})-[r:HAS_READ]->() 
DELETE r

# %%
MATCH (n:Person {name: 'John'})-[r:HAS_READ]->() 
DELETE r

# %% [markdown]
# # Sample code of adjacency matrix and adjacency list in graph with networkx
# ## Install the necessary python libraries

# %%
# !pip install networkx pandas numpy matplotlib

# %% [markdown]
# ## Import library

# %%
import networkx as nx
import numpy as np

# %% [markdown]
# ### Spring layout

# %%
# Instantiate the graph
G = nx.Graph()

edges = [(0, 1, 2.1), (0, 2, 1.5), (0, 3, 2), (0, 5, 10), (1, 3, 1.6), (1, 6, 1.4), 
         (2, 3, 4), (3, 4, 2.5), (4, 5, 1.8), (4, 7, 2.3), (5, 8, 1.5), (8, 9, 1.9)]
# add node/edge pairs
G.add_weighted_edges_from(edges)

pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels = True)

labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
# Out:
# {(0, 1): Text(0.2625274201759993, 0.1300542093239613, '2.1'),
#  (0, 2): Text(0.26737274967582253, -0.06986622482800271, '1.5'),
#  (0, 3): Text(0.16693918669191682, -0.0627651751745794, '2'),
#  (0, 5): Text(-0.03931235454678645, 0.03477204595886422, '10'),
#  (1, 3): Text(0.34484997922102045, 0.02177824700797759, '1.6'),
#  (1, 6): Text(0.6204211923748498, 0.36488927826214224, '1.4'),
#  (2, 3): Text(0.3496953087208437, -0.1781421871439864, '4'),
#  (3, 4): Text(0.09858012717970227, -0.2891499756102405, '2.5'),
#  (5, 4): Text(-0.107671414059001, -0.19161275447679682, '1.8'),
#  (5, 8): Text(-0.4114729723113779, 0.15152166800493472, '1.5'),
#  (4, 7): Text(-0.10095184260776334, -0.591520480730178, '2.3'),
#  (8, 9): Text(-0.8298523039411436, 0.3700013436531581, '1.9')}

# %% [markdown]
# ## Directed graph

# %%
# Instantiate the graph
G = nx.DiGraph()

edges = [(0, 1, 2.1), (0, 2, 1.5), (0, 3, 2), (0, 5, 10), (1, 3, 1.6), (1, 6, 1.4), 
         (2, 3, 4), (3, 4, 2.5), (4, 5, 1.8), (4, 7, 2.3), (5, 8, 1.5), (8, 9, 1.9)]
# add node/edge pairs
G.add_weighted_edges_from(edges)

pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels = True)

labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
# Out:
# {(0, 1): Text(0.1397769728863823, 0.06017877371252628, '2.1'),
#  (0, 2): Text(0.07219069710673272, -0.06378097139247943, '1.5'),
#  (0, 3): Text(0.019924460429630253, -0.10908808657074233, '2'),
#  (0, 5): Text(-0.2877857310094095, 0.088748788947206, '10'),
#  (1, 3): Text(0.28551378739154015, -0.08850554005025628, '1.6'),
#  (1, 6): Text(0.5246144986510646, 0.2567875890682824, '1.4'),
#  (2, 3): Text(0.21792751161189056, -0.21246528515526197, '4'),
#  (3, 4): Text(0.15787370322449434, -0.20136694480288186, '2.5'),
#  (5, 8): Text(-0.598342639959368, 0.1299719046878582, '1.5'),
#  (4, 5): Text(-0.14983648821454543, -0.003530069284933532, '1.8'),
#  (4, 7): Text(0.41870680673417693, -0.2729327112733956, '2.3'),
#  (8, 9): Text(-0.8734630859877223, 0.13986161841316913, '1.9')}

# %% [markdown]
# ## Circular layout

# %%
# Instantiate the graph
G = nx.Graph()

edges = [(0, 1, 2.1), (0, 2, 1.5), (0, 3, 2), (0, 5, 10), (1, 3, 1.6), (1, 6, 1.4), 
         (2, 3, 4), (3, 4, 2.5), (4, 5, 1.8), (4, 7, 2.3), (5, 8, 1.5), (8, 9, 1.9)]
# add node/edge pairs
G.add_weighted_edges_from(edges)

pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels = True)

labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
# Out:
# {(0, 1): Text(0.9045085018604486, 0.29389263494502404, '2.1'),
#  (0, 2): Text(0.6545084884494037, 0.4755282818745524, '1.5'),
#  (0, 3): Text(0.3454914877087385, 0.4755282520722302, '2'),
#  (0, 5): Text(0.09549150410001578, 0.29389263494502404, '10'),
#  (1, 3): Text(0.24999998956918715, 0.7694208723145122, '1.6'),
#  (1, 6): Text(-0.09549149217908687, 0.29389259123363604, '1.4'),
#  (2, 3): Text(-2.3841857793582832e-08, 0.9510565192440406, '4'),
#  (3, 4): Text(-0.5590169783889235, 0.18163560202762602, '2.5'),
#  (5, 4): Text(-0.8090169619976462, -1.5099580141786362e-08, '1.8'),
#  (5, 8): Text(-0.24999993294477502, -0.18163560242446414, '1.5'),
#  (4, 7): Text(-0.5590170230924068, -0.7694208727113503, '2.3'),
#  (8, 9): Text(0.5590170350133357, -0.7694208727113503, '1.9')}

# %% [markdown]
# ## Circular layout in directed graph

# %%
# Instantiate the graph
G = nx.DiGraph()

edges = [(0, 1, 2.1), (0, 2, 1.5), (0, 3, 2), (0, 5, 10), (1, 3, 1.6), (1, 6, 1.4), 
         (2, 3, 4), (3, 4, 2.5), (4, 5, 1.8), (4, 7, 2.3), (5, 8, 1.5), (8, 9, 1.9)]
# add node/edge pairs
G.add_weighted_edges_from(edges)

pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels = True)

labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
# Out:
# {(0, 1): Text(0.9045085018604486, 0.29389263494502404, '2.1'),
#  (0, 2): Text(0.6545084884494037, 0.4755282818745524, '1.5'),
#  (0, 3): Text(0.3454914877087385, 0.4755282520722302, '2'),
#  (0, 5): Text(0.09549150410001578, 0.29389263494502404, '10'),
#  (1, 3): Text(0.24999998956918715, 0.7694208723145122, '1.6'),
#  (1, 6): Text(-0.09549149217908687, 0.29389259123363604, '1.4'),
#  (2, 3): Text(-2.3841857793582832e-08, 0.9510565192440406, '4'),
#  (3, 4): Text(-0.5590169783889235, 0.18163560202762602, '2.5'),
#  (5, 8): Text(-0.24999993294477502, -0.18163560242446414, '1.5'),
#  (4, 5): Text(-0.8090169619976462, -1.5099580141786362e-08, '1.8'),
#  (4, 7): Text(-0.5590170230924068, -0.7694208727113503, '2.3'),
#  (8, 9): Text(0.5590170350133357, -0.7694208727113503, '1.9')}
